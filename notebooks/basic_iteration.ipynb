# %% [markdown]
# # Iterables
#
# Some steps in a neuroimaging analysis are repetitive. Running the same preprocessing on multiple subjects or doing statistical inference on multiple files. To prevent the creation of multiple individual scripts, Nipype has as execution plugin for ``Workflow``, called **``iterables``**.
#
# <img src="../static/images/iterables.png"  width="240">
#
# If you are interested in more advanced procedures, such as synchronizing multiple iterables or using conditional iterables, check out the `synchronize `and `intersource` section in the [`JoinNode`](basic_joinnodes.ipynb) notebook.

# %% [markdown]
# ## Realistic example
#
# Let's assume we have a workflow with two nodes, node (A) does simple skull stripping, and is followed by a node (B) that does isometric smoothing. Now, let's say, that we are curious about the effect of different smoothing kernels. Therefore, we want to run the smoothing node with FWHM set to 2mm, 8mm, and 16mm.

# %%
import os.path as op
from nipype import Node, Workflow

from nipype.interfaces.fsl import BET, IsotropicSmooth

# Initiate a skull stripping Node with BET
skullstrip = Node(BET(mask=True,
                      in_file=op.abspath('data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz')),
                  name="skullstrip")

# %% [markdown]
# Create a smoothing Node with IsotropicSmooth

# %%
isosmooth = Node(IsotropicSmooth(), name='iso_smooth')

# %% [markdown]
# Now, to use ``iterables`` and therefore smooth with different ``fwhm`` is as simple as that:

# %%
isosmooth.iterables = ("fwhm", [4, 8, 16])

# %% [markdown]
# And to wrap it up. We need to create a workflow, connect the nodes and finally, can run the workflow in parallel.

# %%
# Create the workflow
wf = Workflow(name="smoothflow")
wf.base_dir = op.expanduser("output")
wf.connect(skullstrip, 'out_file', isosmooth, 'in_file')

# Run it in parallel (one core for each smoothing kernel)
wf.run('MultiProc', plugin_args={'n_procs': 3})
# Out:
# 191104-15:36:37,968 nipype.workflow INFO:
# 	 Workflow smoothflow settings: ['check', 'execution', 'logging', 'monitoring']
# 191104-15:36:37,976 nipype.workflow INFO:
# 	 Running in parallel.
# 191104-15:36:37,980 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 3/3.
# 191104-15:36:38,46 nipype.workflow INFO:
# 	 [Node] Setting-up "smoothflow.skullstrip" in "/Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/skullstrip".
# 191104-15:36:38,61 nipype.workflow INFO:
# 	 [Node] Running "skullstrip" ("nipype.interfaces.fsl.preprocess.BET"), a CommandLine Interface with command:
# bet /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/skullstrip/sub-01_ses-test_T1w_brain.nii.gz -m
# 191104-15:36:39,982 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 2/3.
#                      Currently running:
#                        * smoothflow.skullstrip
# 191104-15:36:41,880 nipype.workflow INFO:
# 	 [Node] Finished "smoothflow.skullstrip".
# 191104-15:36:41,981 nipype.workflow INFO:
# 	 [Job 0] Completed (smoothflow.skullstrip).
# 191104-15:36:41,989 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 3/3.
# 191104-15:36:42,30 nipype.workflow INFO:
# 	 [Node] Setting-up "smoothflow.iso_smooth" in "/Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_4/iso_smooth".
# 191104-15:36:42,29 nipype.workflow INFO:
# 	 [Node] Setting-up "smoothflow.iso_smooth" in "/Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_16/iso_smooth".
# 191104-15:36:42,32 nipype.workflow INFO:
# 	 [Node] Setting-up "smoothflow.iso_smooth" in "/Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_8/iso_smooth".
# 191104-15:36:42,40 nipype.workflow INFO:
# 	 [Node] Running "iso_smooth" ("nipype.interfaces.fsl.maths.IsotropicSmooth"), a CommandLine Interface with command:
# fslmaths /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/skullstrip/sub-01_ses-test_T1w_brain.nii.gz -s 1.69864 /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_4/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz
# 191104-15:36:42,44 nipype.workflow INFO:
# 	 [Node] Running "iso_smooth" ("nipype.interfaces.fsl.maths.IsotropicSmooth"), a CommandLine Interface with command:
# fslmaths /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/skullstrip/sub-01_ses-test_T1w_brain.nii.gz -s 6.79457 /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_16/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz
# 191104-15:36:42,49 nipype.workflow INFO:
# 	 [Node] Running "iso_smooth" ("nipype.interfaces.fsl.maths.IsotropicSmooth"), a CommandLine Interface with command:
# fslmaths /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/skullstrip/sub-01_ses-test_T1w_brain.nii.gz -s 3.39729 /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/_fwhm_8/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz
# 191104-15:36:43,981 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 13.80/14.40, Free processors: 0/3.
#                      Currently running:
#                        * smoothflow.iso_smooth
#                        * smoothflow.iso_smooth
#                        * smoothflow.iso_smooth
# 191104-15:36:45,755 nipype.workflow INFO:
# 	 [Node] Finished "smoothflow.iso_smooth".
# 191104-15:36:45,984 nipype.workflow INFO:
# 	 [Job 3] Completed (smoothflow.iso_smooth).
# 191104-15:36:45,987 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 14.00/14.40, Free processors: 1/3.
#                      Currently running:
#                        * smoothflow.iso_smooth
#                        * smoothflow.iso_smooth
# 191104-15:36:48,112 nipype.workflow INFO:
# 	 [Node] Finished "smoothflow.iso_smooth".
# 191104-15:36:49,985 nipype.workflow INFO:
# 	 [Job 2] Completed (smoothflow.iso_smooth).
# 191104-15:36:49,987 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 14.20/14.40, Free processors: 2/3.
#                      Currently running:
#                        * smoothflow.iso_smooth
# 191104-15:36:53,786 nipype.workflow INFO:
# 	 [Node] Finished "smoothflow.iso_smooth".
# 191104-15:36:53,991 nipype.workflow INFO:
# 	 [Job 1] Completed (smoothflow.iso_smooth).
# 191104-15:36:53,994 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 14.40/14.40, Free processors: 3/3.

# %% [markdown]
# **Note**, that ``iterables`` is set on a specific node (``isosmooth`` in this case), but ``Workflow`` is needed to expend the graph to three subgraphs with three different versions of the ``isosmooth`` node.
#
# If we visualize the graph with ``exec``, we can see where the parallelization actually takes place.

# %%
# Visualize the detailed graph
from IPython.display import Image
wf.write_graph(graph2use='exec', format='png', simple_form=True)
Image(filename=op.abspath('output/smoothflow/graph_detailed.png'))
# Out:
# 191104-15:36:56,306 nipype.workflow INFO:
# 	 Generated workflow graph: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/output/smoothflow/graph.png (graph2use=exec, simple_form=True).

# %% [markdown]
# If you look at the structure in the workflow directory, you can also see, that for each smoothing, a specific folder was created, i.e. ``_fwhm_16``.

# %%
# !tree  output/smoothflow -I '*txt|*pklz|report*|*.json|*js|*.dot|*.html'
# Out:
# output/smoothflow
# ├── _fwhm_16
# │   └── iso_smooth
# │       ├── _report
# │       └── sub-01_ses-test_T1w_brain_smooth.nii.gz
# ├── _fwhm_4
# │   └── iso_smooth
# │       ├── _report
# │       └── sub-01_ses-test_T1w_brain_smooth.nii.gz
# ├── _fwhm_8
# │   └── iso_smooth
# │       ├── _report
# │       └── sub-01_ses-test_T1w_brain_smooth.nii.gz
# ├── graph.png
# ├── graph_detailed.png
# └── skullstrip
#     ├── _report
#     └── sub-01_ses-test_T1w_brain.nii.gz
#
# 11 directories, 6 files

# %% [markdown]
# Now, let's visualize the results!

# %%
from nilearn import plotting
# %matplotlib inline
# Out:
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/importlib/_bootstrap.py:219: ImportWarning: can't resolve package from __spec__ or __package__, falling back on __name__ and __path__
#   return f(*args, **kwds)

# %%
plotting.plot_anat(
    'data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz', title='original',
    display_mode='z', dim=-1, cut_coords=(-50, -35, -20, -5), annotate=False);

# %%
plotting.plot_anat(
    'output/smoothflow/skullstrip/sub-01_ses-test_T1w_brain.nii.gz', title='skullstripped',
    display_mode='z', dim=-1, cut_coords=(-50, -35, -20, -5), annotate=False);

# %%
plotting.plot_anat(
    'output/smoothflow/_fwhm_4/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz', title='FWHM=4',
    display_mode='z', dim=-0.5, cut_coords=(-50, -35, -20, -5), annotate=False);

# %%
plotting.plot_anat(
    'output/smoothflow/_fwhm_8/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz', title='FWHM=8',
    display_mode='z', dim=-0.5, cut_coords=(-50, -35, -20, -5), annotate=False);

# %%
plotting.plot_anat(
    'output/smoothflow/_fwhm_16/iso_smooth/sub-01_ses-test_T1w_brain_smooth.nii.gz', title='FWHM=16',
    display_mode='z', dim=-0.5, cut_coords=(-50, -35, -20, -5), annotate=False);

# %% [markdown]
# # ``IdentityInterface`` (special use case of ``iterables``)
#
# We often want to start our worflow from creating subgraphs, e.g. for running preprocessing for all subjects. We can easily do it with setting ``iterables`` on the ``IdentityInterface``. The ``IdentityInterface`` interface allows you to create ``Nodes`` that does simple identity mapping, i.e. ``Nodes`` that only work on parameters/strings.
#
#
# For example, you want to start your workflow by collecting anatomical files for 5 subjects.

# %%
# First, let's specify the list of subjects
subject_list = ['01', '02', '03', '04', '05']

# %% [markdown]
# Now, we can create the IdentityInterface Node

# %%
from nipype import IdentityInterface
infosource = Node(IdentityInterface(fields=['subject_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list)]

# %% [markdown]
# That's it. Now, we can connect the output fields of this ``infosource`` node to ``SelectFiles`` and ``DataSink`` nodes.

# %%
from os.path import join as opj, expanduser
from nipype.interfaces.io import SelectFiles, DataSink

anat_file = opj('sub-{subject_id}', 'ses-test', 'anat', 'sub-{subject_id}_ses-test_T1w.nii.gz')

templates = {'anat': anat_file}

selectfiles = Node(SelectFiles(templates,
                               base_directory=op.abspat'data/ds000114'),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=expanduser("output"),
                         container="datasink"),
                name="datasink")

wf_sub = Workflow(name="choosing_subjects")
wf_sub.connect(infosource, "subject_id", selectfiles, "subject_id")
wf_sub.connect(selectfiles, "anat", datasink, "anat_files")
wf_sub.run()
# Out:
# 191104-15:38:14,911 nipype.workflow INFO:
# 	 Workflow choosing_subjects settings: ['check', 'execution', 'logging', 'monitoring']
# 191104-15:38:14,930 nipype.workflow INFO:
# 	 Running serially.
# 191104-15:38:14,931 nipype.workflow INFO:
# 	 [Node] Setting-up "choosing_subjects.selectfiles" in "/private/tmp/tmpzpoax_8z/choosing_subjects/_subject_id_05/selectfiles".
# 191104-15:38:14,934 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 191104-15:38:14,940 nipype.workflow WARNING:
# 	 [Node] Error on "choosing_subjects.selectfiles" (/private/tmp/tmpzpoax_8z/choosing_subjects/_subject_id_05/selectfiles)
# 191104-15:38:14,942 nipype.workflow ERROR:
# 	 Node selectfiles.a4 failed to run on host calcium.mbi.monash.edu.au.
# 191104-15:38:14,944 nipype.workflow ERROR:
# 	 Saving crash info to /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a4-f9e344bd-8a6e-4dfa-8257-18b49605c482.pklz
# Traceback (most recent call last):
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 472, in run
#     result = self._run_interface(execute=True)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 563, in _run_interface
#     return self._run_command(execute)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 643, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 377, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 455, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/io.py", line 1412, in _list_outputs
#     raise IOError(msg)
# OSError: No files were found matching anat template: /private/tmp/tmpzpoax_8z/choosing_subjects/_subject_id_05/selectfiles/data/ds000114/sub-05/ses-test/anat/sub-05_ses-test_T1w.nii.gz
#
# 191104-15:38:14,946 nipype.workflow INFO:
# 	 [Node] Setting-up "choosing_subjects.selectfiles" in "/private/tmp/tmp4o0mv9rp/choosing_subjects/_subject_id_04/selectfiles".
# 191104-15:38:14,950 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 191104-15:38:14,953 nipype.workflow WARNING:
# 	 [Node] Error on "choosing_subjects.selectfiles" (/private/tmp/tmp4o0mv9rp/choosing_subjects/_subject_id_04/selectfiles)
# 191104-15:38:14,955 nipype.workflow ERROR:
# 	 Node selectfiles.a3 failed to run on host calcium.mbi.monash.edu.au.
# 191104-15:38:14,957 nipype.workflow ERROR:
# 	 Saving crash info to /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a3-ff81e5d0-e57e-4170-b7fb-d5893fb86361.pklz
# Traceback (most recent call last):
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 472, in run
#     result = self._run_interface(execute=True)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 563, in _run_interface
#     return self._run_command(execute)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 643, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 377, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 455, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/io.py", line 1412, in _list_outputs
#     raise IOError(msg)
# OSError: No files were found matching anat template: /private/tmp/tmp4o0mv9rp/choosing_subjects/_subject_id_04/selectfiles/data/ds000114/sub-04/ses-test/anat/sub-04_ses-test_T1w.nii.gz
#
# 191104-15:38:14,959 nipype.workflow INFO:
# 	 [Node] Setting-up "choosing_subjects.selectfiles" in "/private/tmp/tmp7j26s6le/choosing_subjects/_subject_id_03/selectfiles".
# 191104-15:38:14,962 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 191104-15:38:14,965 nipype.workflow WARNING:
# 	 [Node] Error on "choosing_subjects.selectfiles" (/private/tmp/tmp7j26s6le/choosing_subjects/_subject_id_03/selectfiles)
# 191104-15:38:14,967 nipype.workflow ERROR:
# 	 Node selectfiles.a2 failed to run on host calcium.mbi.monash.edu.au.
# 191104-15:38:14,969 nipype.workflow ERROR:
# 	 Saving crash info to /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a2-fc9f84fa-fe5a-4c84-b72b-0bddf8ef9ef9.pklz
# Traceback (most recent call last):
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 472, in run
#     result = self._run_interface(execute=True)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 563, in _run_interface
#     return self._run_command(execute)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 643, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 377, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 455, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/io.py", line 1412, in _list_outputs
#     raise IOError(msg)
# OSError: No files were found matching anat template: /private/tmp/tmp7j26s6le/choosing_subjects/_subject_id_03/selectfiles/data/ds000114/sub-03/ses-test/anat/sub-03_ses-test_T1w.nii.gz
#
# 191104-15:38:14,971 nipype.workflow INFO:
# 	 [Node] Setting-up "choosing_subjects.selectfiles" in "/private/tmp/tmpqnog4hmx/choosing_subjects/_subject_id_02/selectfiles".
# 191104-15:38:14,974 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 191104-15:38:14,978 nipype.workflow WARNING:
# 	 [Node] Error on "choosing_subjects.selectfiles" (/private/tmp/tmpqnog4hmx/choosing_subjects/_subject_id_02/selectfiles)
# 191104-15:38:14,980 nipype.workflow ERROR:
# 	 Node selectfiles.a1 failed to run on host calcium.mbi.monash.edu.au.
# 191104-15:38:14,981 nipype.workflow ERROR:
# 	 Saving crash info to /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a1-7802b642-acb3-4fc0-80ea-2c24f40d7f5c.pklz
# Traceback (most recent call last):
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 472, in run
#     result = self._run_interface(execute=True)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 563, in _run_interface
#     return self._run_command(execute)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 643, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 377, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 455, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/io.py", line 1412, in _list_outputs
#     raise IOError(msg)
# OSError: No files were found matching anat template: /private/tmp/tmpqnog4hmx/choosing_subjects/_subject_id_02/selectfiles/data/ds000114/sub-02/ses-test/anat/sub-02_ses-test_T1w.nii.gz
#
# 191104-15:38:14,983 nipype.workflow INFO:
# 	 [Node] Setting-up "choosing_subjects.selectfiles" in "/private/tmp/tmpv20pj5_t/choosing_subjects/_subject_id_01/selectfiles".
# 191104-15:38:14,987 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 191104-15:38:14,990 nipype.workflow WARNING:
# 	 [Node] Error on "choosing_subjects.selectfiles" (/private/tmp/tmpv20pj5_t/choosing_subjects/_subject_id_01/selectfiles)
# 191104-15:38:14,992 nipype.workflow ERROR:
# 	 Node selectfiles.a0 failed to run on host calcium.mbi.monash.edu.au.
# 191104-15:38:14,994 nipype.workflow ERROR:
# 	 Saving crash info to /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a0-84fb8b44-093b-4a7c-8127-57417d263f32.pklz
# Traceback (most recent call last):
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/plugins/linear.py", line 48, in run
#     node.run(updatehash=updatehash)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 472, in run
#     result = self._run_interface(execute=True)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 563, in _run_interface
#     return self._run_command(execute)
#   File "/Users/tclose/git/ni/nipype/nipype/pipeline/engine/nodes.py", line 643, in _run_command
#     result = self._interface.run(cwd=outdir)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 377, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/base/core.py", line 455, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/Users/tclose/git/ni/nipype/nipype/interfaces/io.py", line 1412, in _list_outputs
#     raise IOError(msg)
# OSError: No files were found matching anat template: /private/tmp/tmpv20pj5_t/choosing_subjects/_subject_id_01/selectfiles/data/ds000114/sub-01/ses-test/anat/sub-01_ses-test_T1w.nii.gz
#
# 191104-15:38:14,995 nipype.workflow INFO:
# 	 ***********************************
# 191104-15:38:14,996 nipype.workflow ERROR:
# 	 could not run node: choosing_subjects.selectfiles.a4
# 191104-15:38:14,997 nipype.workflow INFO:
# 	 crashfile: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a4-f9e344bd-8a6e-4dfa-8257-18b49605c482.pklz
# 191104-15:38:14,997 nipype.workflow ERROR:
# 	 could not run node: choosing_subjects.selectfiles.a3
# 191104-15:38:14,998 nipype.workflow INFO:
# 	 crashfile: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a3-ff81e5d0-e57e-4170-b7fb-d5893fb86361.pklz
# 191104-15:38:14,998 nipype.workflow ERROR:
# 	 could not run node: choosing_subjects.selectfiles.a2
# 191104-15:38:14,999 nipype.workflow INFO:
# 	 crashfile: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a2-fc9f84fa-fe5a-4c84-b72b-0bddf8ef9ef9.pklz
# 191104-15:38:15,1 nipype.workflow ERROR:
# 	 could not run node: choosing_subjects.selectfiles.a1
# 191104-15:38:15,1 nipype.workflow INFO:
# 	 crashfile: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a1-7802b642-acb3-4fc0-80ea-2c24f40d7f5c.pklz
# 191104-15:38:15,2 nipype.workflow ERROR:
# 	 could not run node: choosing_subjects.selectfiles.a0
# 191104-15:38:15,3 nipype.workflow INFO:
# 	 crashfile: /Users/tclose/Documents/Workshops/2019-11-15-N.A.B.-workshop/nipype_arcana_workshop/notebooks/crash-20191104-153814-tclose-selectfiles.a0-84fb8b44-093b-4a7c-8127-57417d263f32.pklz
# 191104-15:38:15,3 nipype.workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-c35674891fdf> in <module>()
#      18 wf_sub.connect(infosource, "subject_id", selectfiles, "subject_id")
#      19 wf_sub.connect(selectfiles, "anat", datasink, "anat_files")
# ---> 20 wf_sub.run()
#
# ~/git/ni/nipype/nipype/pipeline/engine/workflows.py in run(self, plugin, plugin_args, updatehash)
#     597         if str2bool(self.config['execution']['create_report']):
#     598             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 599         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     600         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     601         if str2bool(self.config['execution']['write_provenance']):
#
# ~/git/ni/nipype/nipype/pipeline/plugins/linear.py in run(self, graph, config, updatehash)
#      69
#      70         os.chdir(old_wd)  # Return wherever we were before
# ---> 71         report_nodes_not_run(notrun)
#
# ~/git/ni/nipype/nipype/pipeline/plugins/tools.py in report_nodes_not_run(notrun)
#      80                 logger.debug(subnode._id)
#      81         logger.info("***********************************")
# ---> 82         raise RuntimeError(('Workflow did not execute cleanly. '
#      83                             'Check log for details'))
#      84
#
# RuntimeError: Workflow did not execute cleanly. Check log for details

# %% [markdown]
# Now we can check that five anatomicl images are in ``anat_files`` directory:

# %%
! ls -lh  output/datasink/anat_files/

# %% [markdown]
# This was just a simple example of using ``IdentityInterface``, but a complete example of preprocessing workflow you can find in [Preprocessing Example](example_preprocessing.ipynb)).

# %% [markdown]
# ## Exercise 1
# Create a workflow to calculate various powers of ``2`` using  two nodes, one for ``IdentityInterface`` with ``iterables``, and one for ``Function`` interface to calculate the power of ``2``.

# %%
# write your solution here

# %%
# lets start from the Identity node
from nipype import Function, Node, Workflow
from nipype.interfaces.utility import IdentityInterface

iden = Node(IdentityInterface(fields=['number']), name="identity")
iden.iterables = [("number", range(8))]

# %%
# the second node should use the Function interface
def power_of_two(n):
    return 2**n

# Create Node
power = Node(Function(input_names=["n"],
                      output_names=["pow"],
                      function=power_of_two),
              name='power')

# %%
#and now the workflow
wf_ex1 = Workflow(name="exercise1")
wf_ex1.connect(iden, "number", power, "n")
res_ex1 = wf_ex1.run()

# we can print the results
for i in range(8):
    print(list(res_ex1.nodes())[i].result.outputs)
